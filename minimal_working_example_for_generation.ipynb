# %% [markdown]
# # Minimal-working example for generation
#
# Reference: https://github.com/NVlabs/stylegan2-ada/issues/17

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# %rm -rf stylegan2-ada/
# !git clone https://github.com/NVlabs/stylegan2-ada.git
# Out:
# Cloning into 'stylegan2-ada'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 61 (delta 1), reused 6 (delta 1), pack-reused 52
# Unpacking objects: 100% (61/61), done.

# %%
out_dir='out'
seed=0
network='https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/metfaces.pkl'

# !python stylegan2-ada/generate.py --outdir={out_dir} --seeds={seed} \
 --network={network}
# Out:
# Loading networks from "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/metfaces.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
# Generating image for seed 0 (0/1) ...

# %%
import cv2
from google.colab.patches import cv2_imshow

img_name = '{}/seed{:04d}.png'.format(out_dir, seed)
img_shape = (256, 256)

print('Image: {}'.format(img_name))

img = cv2.imread(img_name)
resized_img = cv2.resize(img, img_shape)
cv2_imshow(resized_img)
# Out:
# Image: out/seed0000.png
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F9C1326BDD8>
